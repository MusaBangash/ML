# %%
import pandas as pd 
import numpy as np

# %%
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("homeprices.csv")

# %%
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("area(sq ft)")
plt.ylabel("price(US $)")
plt.scatter(df.area,df.price,color="red",marker="+")

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15112\2097515585.py in <module>
# ----> 1 reg=linear_model.LinearRegression()
#       2 reg.fit(df[['area']],df.price)
#
# NameError: name 'linear_model' is not defined

# %%
# %matplotlib inline
plt.xlabel("area(sq ft)")
plt.ylabel("price(US $)")
plt.scatter(df.area,df.price,color="red",marker="+")
plt.plot(df.area,reg.predict(df[['area']]),color="blue")

# %%
reg.predict([[5000]])
# Out:
# C:\Users\musab\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
reg.coef_ #value of coefficent
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
df2=pd.read_csv("areas.csv")

# %%
df2.head(3)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300

# %%
p= reg.predict(df2)

# %%
df2["prices"]=p

# %%
df2.to_csv("prediction.csv",index=False)
